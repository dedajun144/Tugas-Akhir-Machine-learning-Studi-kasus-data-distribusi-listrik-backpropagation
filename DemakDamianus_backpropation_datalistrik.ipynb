#         -0.35348133, -0.35706751, -0.36233915, -0.37031934, -0.37876522],
#        [-0.12343947, -0.13350935, -0.14554433, -0.1425002 , -0.13217256,
#         -0.12607722, -0.1297447 , -0.12439386, -0.08869872, -0.10567108],
#        [-0.34407347, -0.34278803, -0.34364238, -0.34302947, -0.34561508,
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=( 128, 64, 32), activation="relu", random_state=1,max_iter=20000).fit(X_trainscaled, y_train)
y_pred = clf.predict(X_testscaled)
x_pred = clf.predict(X_trainscaled)
print(clf.score(X_trainscaled, y_train))
print(clf.score(X_testscaled, y_test))
# Out:
# C:\Users\demak\anaconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1118: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9565217391304348
# 0.0

# %%
print(x_pred)
print(y_pred)
# Out:
# ['408' '175.26' '945.24' '433' '50.86' '4,184.30' '38.79' '39.8' '41.19'
#  '79.73' '265.47' '1,100.99' '6.15' '3082.97' '183.47' '190.56'
#  '14,233.05' '997.88' '24,077.60' '39.99' '6.15' '334.89' '8,332.48']

# %% [markdown]
# # MPL-BP Regression

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import pandas as pd

# %%
df = pd.read_csv('datalistrik.csv')
x=df[['2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']]
y=df[['2021']]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,random_state=1, test_size=0.2)

# %%
sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

# %%
reg = MLPRegressor(hidden_layer_sizes=(5),activation="relu" ,random_state=1, max_iter=200000).fit(X_trainscaled, y_train)
# Out:
# C:\Users\demak\anaconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred=reg.predict(X_testscaled)
score = r2_score(y_pred, y_test)
print("The Score with ", score)
#reg.predict(X_test[:2])
reg.predict(x)
# Out:
# The Score with  0.992150369879066
# C:\Users\demak\anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# array([8.86001047e+05, 1.46776779e+07, 4.60730917e+06, 3.20032018e+06,
#        8.34666707e+05, 4.91804136e+06, 3.78385084e+05, 5.25853615e+06,
#        1.11041612e+06, 4.22664302e+05, 2.04028023e+07, 1.15702680e+08,
#        3.99581739e+07, 1.29096901e+06, 7.95585733e+07, 6.82485892e+07,
#        1.00404571e+06, 7.84770501e+05, 2.64742996e+05, 1.00077007e+06,
#        6.30059247e+05, 1.97960383e+06, 1.77719285e+06, 2.21846028e+05,
#        1.85556243e+06, 2.38956078e+05, 6.10471323e+06, 2.73920889e+05,
#        1.81875694e+05, 1.78041674e+05, 5.64202750e+04, 3.06127633e+04,
#        4.53626473e+04, 4.95079682e+04])

# %%
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("RMSE : ", rmse)
# Out:
# RMSE :  503.53093422485296

# %% [markdown]
# # Simple MPL-BP Regression

# %%
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=3300, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
regr = MLPRegressor(random_state=1, max_iter=150000).fit(X_train, y_train)
len(X_test)
regr.predict(X_test[:2])
# Out:
# array([-153.53951499,   29.61411517])

# %%
regr.score(X_test, y_test)
# Out:
# 0.9988002942492981

# %%
regr.predict(X)
# Out:
# array([ 184.99902706, -340.80608656,  141.67786624, ...,   35.08770245,
#         178.38319561,   46.72796093])
